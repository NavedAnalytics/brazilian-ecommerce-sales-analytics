# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
orders=pd.read_csv("../datasets/Raw_Datasets/olist_orders_dataset.csv")
products=pd.read_csv("../datasets/Raw_Datasets/olist_products_dataset.csv")
payments=pd.read_csv("../datasets/Raw_Datasets/olist_order_payments_dataset.csv")
sellers=pd.read_csv("../datasets/Raw_Datasets/olist_sellers_dataset.csv")
reviews=pd.read_csv("../datasets/Raw_Datasets/olist_order_reviews_dataset.csv")
order_items=pd.read_csv("../datasets/Raw_Datasets/olist_order_items_dataset.csv")
customers=pd.read_csv("../datasets/Raw_Datasets/olist_customers_dataset.csv")
translation=pd.read_csv("../datasets/Raw_Datasets/product_category_name_translation.csv")

# %% [markdown]
# DATA CLEANING OF RAW DATAS

# %% [markdown]
# 1.customers

# %%
print(customers.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
print(customers.dtypes)
# Out:
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object

# %%
print(customers.isnull().sum())
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print(customers['customer_id'].duplicated().sum())
# Out:
# 0

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.to_csv("../datasets/Cleaned_Datasets/olist_customers_dataset_clean.csv",index=False)

# %% [markdown]
# 2.Orders

# %%
print(orders.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
print(orders.isnull().sum())
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders['order_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.to_csv("../datasets/Cleaned_Datasets/olist_orders_dataset_clean.csv",index=False)

# %% [markdown]
# 3.products

# %%
print(products.head())
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
print(products.dtypes)
# Out:
# product_id                        str
# product_category_name             str
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
print(products.isnull().sum())
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products['product_category_name']=products['product_category_name'].fillna('Unknown')
products['product_name_lenght']=products['product_name_lenght'].fillna(products['product_name_lenght']).median()
products['product_description_lenght']=products['product_description_lenght'].fillna(products['product_description_lenght']).median()
products['product_photos_qty']=products['product_photos_qty'].fillna(products['product_photos_qty']).median()
products['product_weight_g']=products['product_weight_g'].fillna(products['product_weight_g']).median()
products['product_length_cm']=products['product_length_cm'].fillna(products['product_length_cm']).median()
products['product_height_cm']=products['product_height_cm'].fillna(products['product_height_cm']).median()
products['product_width_cm']=products['product_width_cm'].fillna(products['product_width_cm']).median()

# %%
print(products.isnull().sum())
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
products['product_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.to_csv("../datasets/Cleaned_Datasets/olist_products_dataset_clean.csv",index=False)

# %% [markdown]
# 3.sellers

# %%
print(sellers.head())
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
print(sellers.dtypes)
# Out:
# seller_id                   str
# seller_zip_code_prefix    int64
# seller_city                 str
# seller_state                str
# dtype: object

# %%
print(sellers.isnull().sum())
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellers['seller_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers.to_csv("../datasets/Cleaned_Datasets/olist_sellers_dataset_clean.csv",index=False)

# %% [markdown]
# 4.reviews

# %%
print(reviews.head())
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
print(reviews.dtypes)
# Out:
# review_id                    str
# order_id                     str
# review_score               int64
# review_comment_title         str
# review_comment_message       str
# review_creation_date         str
# review_answer_timestamp      str
# dtype: object

# %%
reviews['review_creation_date']=pd.to_datetime(reviews['review_creation_date'])
reviews['review_answer_timestamp'] = pd.to_datetime(reviews['review_answer_timestamp'])

# %%
print(reviews.isnull().sum())
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
reviews['review_comment_title']=reviews['review_comment_title'].fillna('Unknown')
reviews['review_comment_message']=reviews['review_comment_message'].fillna('Not Review')

# %%
reviews['review_id'].duplicated().sum()
# Out:
# np.int64(814)

# %% [markdown]
# We do not delete review_id duplicates because one person can review many orders.

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
reviews.to_csv("../datasets/Cleaned_Datasets/olist_order_reviews_dataset_clean.csv",index=False)

# %%
print(payments.head())
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
print(payments.dtypes)
# Out:
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
print(payments.isnull().sum())
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
payments.to_csv("../datasets/Cleaned_Datasets/olist_order_payments_dataset_clean.csv",index=False)

# %%
print(order_items.head())
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
print(order_items.dtypes)
# Out:
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object

# %%
order_items['shipping_limit_date']=pd.to_datetime(order_items['shipping_limit_date'])

# %%
print(order_items.isnull().sum())
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_items.to_csv("../datasets/Cleaned_Datasets/olist_order_items_dataset_clean.csv",index=False)

# %%
print(translation.head())
# Out:
#    Unnamed: 0   product_category_name product_category_name_english
# 0           0            beleza_saude                 health_beauty
# 1           1  informatica_acessorios         computers_accessories
# 2           2              automotivo                          auto
# 3           3         cama_mesa_banho                bed_bath_table
# 4           4        moveis_decoracao               furniture_decor

# %%
translation=translation.drop(columns=["Unnamed: 0"])

# %%
print(translation.dtypes)
# Out:
# product_category_name            str
# product_category_name_english    str
# dtype: object

# %%
print(translation['product_category_name'].isnull().sum())
# Out:
# 0

# %%
print(translation.isnull().sum())
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
translation.to_csv("../datasets/Cleaned_Datasets/product_category_name_translation_clean.csv",index=False)

# %%
Customers=pd.read_csv("../datasets/Cleaned_Datasets/olist_customers_dataset_clean.csv")

Payments=pd.read_csv("../datasets/Cleaned_Datasets/olist_order_payments_dataset_clean.csv")

Order_items=pd.read_csv("../datasets/Cleaned_Datasets/olist_order_items_dataset_clean.csv")

Reviews=pd.read_csv("../datasets/Cleaned_Datasets/olist_order_reviews_dataset_clean.csv")


Orders=pd.read_csv("../datasets/Cleaned_Datasets/olist_orders_dataset_clean.csv")


Products=pd.read_csv("../datasets/Cleaned_Datasets/olist_products_dataset_clean.csv")


Sellers=pd.read_csv("../datasets/Cleaned_Datasets/olist_sellers_dataset_clean.csv")


Translation=pd.read_csv("../datasets/Cleaned_Datasets/product_category_name_translation_clean.csv")

# %% [markdown]
# Now,Mering cleaned Tables

# %%
Products=Products.merge(
    Translation,
    on="product_category_name",
    how='left'
)





# Main dataset
df = Orders.merge(
    Customers,
    on="customer_id",
    how="left"
)

df = df.merge(
    Order_items,
    on="order_id",
    how="left"
)

df = df.merge(
    Products,
    on="product_id",
    how="left"
)

df = df.merge(
    Sellers,
    on="seller_id",
    how="left"
)

df = df.merge(
    Payments,
    on="order_id",
    how="left"
)

df = df.merge(
    Reviews,
    on="order_id",
    how="left"
)

# %%
# Filling the missing product category translation ✅
# that are 
# Unknown = 610
# portateis_cozinha_e_preparadores_de_alimentos = 10
# pc_gamer = 3
#missed durning(merging tables with left join)



df.loc[df["product_category_name"] == "portateis_cozinha_e_preparadores_de_alimentos","product_category_name_english"] = "portable_kitchen_and_food_preparers"

df.loc[df["product_category_name"] == "pc_gamer","product_category_name_english"] = "gaming_pc"

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'product_category_name_english', 'seller_zip_code_prefix', 'seller_city', 'seller_state', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value', 'review_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp']

# %%
print(df.shape[1])
# Out:
# 40

# %% [markdown]
# Now, Data Cleaning Starts

# %% [markdown]
# 1.Check the Dataset

# %%
print(df.shape)
# Out:
# (119143, 40)

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119141  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119142  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %% [markdown]
# 2.Check for Dupicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 3. Check missing values

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# order_delivered_customer_date    3421
# product_category_name_english    2542
# order_delivered_carrier_date     2086
# review_answer_timestamp           997
# review_id                         997
# review_score                      997
# review_creation_date              997
# review_comment_message            997
# review_comment_title              997
# product_width_cm                  833
# seller_zip_code_prefix            833
# seller_city                       833
# product_length_cm                 833
# product_weight_g                  833
# seller_state                      833
# shipping_limit_date               833
# product_description_lenght        833
# seller_id                         833
# product_id                        833
# order_item_id                     833
# product_name_lenght               833
# product_category_name             833
# freight_value                     833
# price                             833
# product_photos_qty                833
# ...

# %%
df[df["product_id"].isna()][["order_id", "order_status"]].head(20)
# Out:
#                               order_id order_status
# 319   8e24261a7e58791d10cb1bf9da94df5c  unavailable
# 702   c272bcd21c287498b4883c7512019702  unavailable
# 828   37553832a3a89c9b2db59701c357ca67  unavailable
# 887   d57e15fb07fd180f06ab3926b39edcd2  unavailable
# 1362  00b1cb0320190ca0daa2c88b35206009     canceled
# 1395  2f634e2cebf8c0283e7ef0989f77d217  unavailable
# 1897  ee0db22a8e742b752914016708470ec8  unavailable
# 2142  ed3efbd3a87bea76c2812c66a0b32219     canceled
# 2180  6ad57aecbae806a7e9cc2cdb6b380711  unavailable
# 2232  df8282afe61008dc26c6c31011474d02     canceled
# 2429  8d4c637f1accf7a88a4555f02741e606     canceled
# 2570  9f3458f0433d4cfa472f4682654b8d49  unavailable
# 2586  7a9d4c7f9b068337875b95465330f2fc     canceled
# 2750  f0df036e9be21fc238f131bbfcdde769  unavailable
# 2771  86f0bcd9b426a2c1022ae317c7f27be6  unavailable
# 3178  98fe01bc254b759c1f2c11d77c2891d5  unavailable
# 3179  98fe01bc254b759c1f2c11d77c2891d5  unavailable
# ...

# %%
df[df["product_id"].isna()]["order_status"].value_counts()
# Out:
# order_status
# unavailable    645
# canceled       180
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %%
df[df["product_id"].isna()].head(20)
# Out:
#                               order_id                       customer_id  \
# 319   8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 702   c272bcd21c287498b4883c7512019702  9582c5bbecc65eb568e2c1d839b5cba1
# 828   37553832a3a89c9b2db59701c357ca67  7607cd563696c27ede287e515812d528
# 887   d57e15fb07fd180f06ab3926b39edcd2  470b93b3f1cde85550fc74cd3a476c78
# 1362  00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1395  2f634e2cebf8c0283e7ef0989f77d217  7353b0fb8e8d9675e3a704c60ca44ebe
# 1897  ee0db22a8e742b752914016708470ec8  aae50600d30bf2efe013ca4c1754ded7
# 2142  ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 2180  6ad57aecbae806a7e9cc2cdb6b380711  d31dbd02ac052d662285f678f8994326
# 2232  df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2429  8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2570  9f3458f0433d4cfa472f4682654b8d49  99ebfafde8b9e58fd12db9d5cc83132f
# ...

# %% [markdown]
# So,same 833 row are missing so theres a reason behind  that unavailable and canceled orders(takes all rows from orders left join but not from other rows,unmatched).

# %%
# Step 2: Fill product category
df["product_category_name_english"] = (
    df["product_category_name_english"]
      .fillna("Unknown")
)

# %% [markdown]
# product_category_name_english is missing name because one product appears in many order so i filled unknown.

# %%
# Step3- Fill reviews category

df["review_comment_title"] = (
    df["review_comment_title"]
      .fillna("No Review")
)

df["review_comment_message"] = (
    df["review_comment_message"]
      .fillna("No Review")
)

# %% [markdown]
# in these reviews category columns i filled unknown .

# %%
df[df["payment_value"].isna()][["product_id","product_category_name_english","seller_id","seller_state","payment_sequential","payment_installments"]]
# Out:
#                              product_id product_category_name_english  \
# 36864  5a6b04657a4c5ee34285d1e4619a96b4                 health_beauty
# 36865  5a6b04657a4c5ee34285d1e4619a96b4                 health_beauty
# 36866  5a6b04657a4c5ee34285d1e4619a96b4                 health_beauty
#
#                               seller_id seller_state  payment_sequential  \
# 36864  ecccfa2bb93b34a3bf033cc5d1dcdc69           PR                 NaN
# 36865  ecccfa2bb93b34a3bf033cc5d1dcdc69           PR                 NaN
# 36866  ecccfa2bb93b34a3bf033cc5d1dcdc69           PR                 NaN
#
#        payment_installments
# 36864                   NaN
# 36865                   NaN
# 36866                   NaN

# %% [markdown]
# So, in payment_sequential,payment_type,payment_installments,payment_value are missing 3 rws because of data problems means data entry and data not avaliable.(not by left join
# )

# %%
df=df.dropna(subset=["payment_sequential", "payment_type","payment_installments","payment_value"])

# %%
df[df["order_delivered_carrier_date"].isna()]["order_status"].value_counts()
# Out:
# order_status
# canceled       670
# unavailable    652
# invoiced       378
# processing     376
# created          5
# approved         3
# delivered        2
# Name: count, dtype: int64

# %%
df[df["order_delivered_customer_date"].isna()]["order_status"].value_counts()
# Out:
# order_status
# shipped        1256
# canceled        743
# unavailable     652
# invoiced        378
# processing      376
# delivered         8
# created           5
# approved          3
# Name: count, dtype: int64

# %% [markdown]
# In these order_delvered_carrier_date and order_delivered_customer_date they are missing because of mostly are cancelled,unavailable,
#  so i leave it .

# %% [markdown]
# order_delivered_customer_date have missing values 3421 & order_delivered_carrier_date have 2086 (These are usually canceled, unavailable, or not-yet-delivered orders.)
#
# product_category_name_english	2542	(I Filled with "Unknown".)
#
# review_id, review_score, review_creation_date, review_answer_timestamp	are 997 missing	(so i keep as NaN (orders without reviews).
#
# review_comment_title, review_comment_message	missing are 997     (so i filled with "No Review" .)
#
# Product columns (product_id, price, freight_value, shipping_limit_date, etc.)& Seller columns (seller_id, seller_city, seller_state)    -Missing-833 columns (beacause of usually canceled,unavailable,or not_yet-delivered orders.so i keepeed it NaN.)

# %% [markdown]
# 4.Checking Data Types of each columns

# %%
df.dtypes
# Out:
# order_id                             str
# customer_id                          str
# order_status                         str
# order_purchase_timestamp             str
# order_approved_at                    str
# order_delivered_carrier_date         str
# order_delivered_customer_date        str
# order_estimated_delivery_date        str
# customer_unique_id                   str
# customer_zip_code_prefix           int64
# customer_city                        str
# customer_state                       str
# order_item_id                    float64
# product_id                           str
# seller_id                            str
# shipping_limit_date                  str
# price                            float64
# freight_value                    float64
# product_category_name                str
# product_name_lenght              float64
# product_description_lenght       float64
# product_photos_qty               float64
# product_weight_g                 float64
# ...

# %% [markdown]
# Change them to datetime datatypes from str
#
# order_purchase_timestamp             str
#
# order_approved_at                    str
#
# order_delivered_carrier_date         str
#
# order_delivered_customer_date        str
#
# order_estimated_delivery_date        str
#
# shipping_limit_date                  str
#
# review_creation_date                 str
#
# review_answer_timestamp              str

# %%
date_cols = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date",
    "shipping_limit_date",
    "review_creation_date",
    "review_answer_timestamp"
]

for col in date_cols:
    df[col] = pd.to_datetime(df[col])
    print(col)
# Out:
# order_purchase_timestamp
# order_approved_at
# order_delivered_carrier_date
# order_delivered_customer_date
# order_estimated_delivery_date
# shipping_limit_date
# review_creation_date
# review_answer_timestamp

# %% [markdown]
# Changed str to datetime columns

# %%
print(df.dtypes)
# Out:
# order_id                                    str
# customer_id                                 str
# order_status                                str
# order_purchase_timestamp         datetime64[us]
# order_approved_at                datetime64[us]
# order_delivered_carrier_date     datetime64[us]
# order_delivered_customer_date    datetime64[us]
# order_estimated_delivery_date    datetime64[us]
# customer_unique_id                          str
# customer_zip_code_prefix                  int64
# customer_city                               str
# customer_state                              str
# order_item_id                           float64
# product_id                                  str
# seller_id                                   str
# shipping_limit_date              datetime64[us]
# price                                   float64
# freight_value                           float64
# product_category_name                       str
# product_name_lenght                     float64
# ...

# %% [markdown]
# Feature Engineering

# %%
# 1. Create Purchase Year
df["Purchase_Year"] = df["order_purchase_timestamp"].dt.year

# 2. Create Purchase Month
df["Purchase_Month"] = df["order_purchase_timestamp"].dt.month_name()

# 3. Create Quarter
df["Quarter"] = "Q"+df["order_purchase_timestamp"].dt.quarter.astype(str)

# 4. Create Day of Week
df["Day_of_Week"] = df["order_purchase_timestamp"].dt.day_name()

# 5. Calculate Delivery Days
df["Delivery_Days"] = (
    df["order_delivered_customer_date"] -
    df["order_purchase_timestamp"]
).dt.days

# 3.Create hour column
df["Hour"]=df["order_purchase_timestamp"].dt.hour


def timeofday(hour):
    if 5<=hour<12:
        return 'Morning'
    if 12<=hour<17:
        return 'Afternoon'
    if 17<=hour<21:
        return 'Evening'
    else:
        return "Night"
    
df['time_of_day']=df['Hour'].apply(timeofday)

# Cretae total price column
df['total_price']=df['price']+df['freight_value']


            
# 7. Check for negative delivery days
print(df[df["Delivery_Days"] < 0])
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm, product_category_name_english, seller_zip_code_prefix, seller_city, seller_state, payment_sequential, payment_type, payment_installments, payment_value, review_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp, Purchase_Year, Purchase_Month, Quarter, Day_of_Week, Delivery_Days, Hour, time_of_day, total_price]
# Index: []
#
# [0 rows x 48 columns]

# %%
# 7. Check for negative delivery days
(df["Delivery_Days"] < 0).sum()
# Out:
# np.int64(0)

# %%
df.to_csv("../datasets/Merged_Table/olist_ecommerce_clean.csv",index=False)

# %% [markdown]
# So. no Delivery_Days are negative.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import pandas as pd

plt.style.use('bmh')

fig, ax = plt.subplots(figsize=(12,6))


# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

month_order = [
    'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]

# Group revenue
monthly_revenue = delivered_orders.groupby('Purchase_Month')['total_price'].sum().reindex(month_order, fill_value=0)   # Ensures Jan-Dec order

# Plot
ax.plot(
    monthly_revenue.index,
    monthly_revenue.values,
    marker='o',
    linewidth=3,
    color='blue',
    
)

# Titles
ax.set_title("Monthly Revenue Trend", fontsize=24, fontweight='bold')
ax.set_xlabel("Months", fontsize=16, fontweight='bold')
ax.set_ylabel("Total Revenue", fontsize=16, fontweight='bold')

# Format Y-axis as Millions
ax.yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f'{x/1e6:.1f}M')
)

# Show every month on x-axis
ax.set_xticks(range(len(month_order)))
ax.set_xticklabels(month_order, rotation=45, fontsize=16)

ax.tick_params(axis='y', labelsize=13)

plt.grid(alpha=0.7)
plt.tight_layout()


plt.savefig('../charts/Chart1_Monthly_Revenue_Trend.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
print(df.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

plt.style.use('bmh')

fig, ax = plt.subplots(figsize=(12,8))

revenue_product_category = (
    df.groupby('product_category_name_english')['total_price']
      .sum()
      .sort_values(ascending=False)
      .head(10)
      .sort_values()
)

revenue_product_category.plot(
    kind='barh',
    color='steelblue',
    ax=ax
)

ax.set_title(
    "Top 10 Product Categories by Revenue",
    fontsize=24,
    fontweight='bold'
)

ax.set_xlabel(
    "Revenue",
    fontsize=15,
    fontweight='bold'
)

ax.set_ylabel(
    "Product Category",
    fontsize=15,
    fontweight='bold',
)

ax.xaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f'{x/1e6:.1f}M')
)

for container in ax.containers:
    ax.bar_label(
        container,
        fmt='%.1fM',
        labels=[f'{v/1e6:.2f}M' for v in revenue_product_category.values],
        padding=4,
        fontsize=14
    )

ax.tick_params(axis='both', labelsize=15)

plt.grid(axis='x', alpha=0.7)
plt.tight_layout()


plt.savefig('../charts/Chart2_Top_10_Product_Categories_by_Revenue.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
plt.style.use('bmh')
plt.figure(figsize=(10,6))
payment_methods= df['payment_type'].value_counts()
bars=plt.bar(payment_methods.index,payment_methods.values,color='purple')
plt.bar_label(bars,padding=3,fontsize=14)
plt.title('Payment Method Distribution',fontsize=24,fontweight='bold')  
plt.xlabel(
    "Payment Methods",
    fontsize=15,
    fontweight='bold',color='orange'
)
plt.ylabel(
    "Count of Payment Methods",
    fontsize=15,
    fontweight='bold',
)
plt.xticks(fontsize=15,fontweight='bold')
plt.yticks(fontsize=15,fontweight='bold')

plt.tight_layout()


plt.savefig('../charts/Chart4_Payment_Method_Distribution.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(12,5))
order_time=df.groupby('time_of_day')['order_id'].nunique().reindex(['Morning','Afternoon','Evening','Night'])
bars=plt.bar(order_time.index,order_time.values,color=['navy'])
plt.bar_label(bars,padding=3,fontsize=14,fontweight='bold')
plt.title('Orders by Time of Day',fontsize=22,fontweight='bold')  
plt.xlabel(
    "Time of Day",
    fontsize=15,
    fontweight='bold',color='orange'
)
plt.ylabel(
    "No. of Orders",
    fontsize=15,
    fontweight='bold',color='red'
)
plt.xticks(fontsize=15,fontweight='bold')
plt.yticks(fontsize=15,fontweight='bold')
plt.grid(axis='y',alpha=0.7)
plt.tight_layout()


plt.savefig('../charts/Chart5_Orders_by_Time_of_Day.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %%
import matplotlib.ticker as ticker
plt.style.use('seaborn-v0_8-talk')
fig,ax=plt.subplots(figsize=(10,6))


# Remove all rows of delivered orders
delivered_orders=df[df['order_status']=='delivered']

revenuebyprdcat=delivered_orders.groupby('product_category_name_english')['total_price'].sum().nlargest(10).iloc[::-1]

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x*1e-6:.2f}M'))

bars=ax.barh(revenuebyprdcat.index,revenuebyprdcat.values,color='red')
ax.bar_label(bars,padding=3,fontsize=14,labels=[f'{v*1e-6:.2f}M' for v in revenuebyprdcat.values])
ax.set_title('Revenue by Product Category',fontsize=24,fontweight='bold')  
ax.set_xlabel(
    "Sum of Payment Values",
    fontsize=15,
    fontweight='bold',color='orange'
)
ax.set_ylabel(
    "Product Category Names in English",
    fontsize=15,
    fontweight='bold',color='red'
)
ax.tick_params(axis='x',labelsize=15)
ax.tick_params(axis='y',labelsize=15)
ax.grid(axis='y',alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

plt.style.use('seaborn-v0_8-talk')

# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

order_category_revenue = (delivered_orders.groupby(['order_id', 'product_category_name_english']).agg(Revenue=('total_price', 'sum') ).reset_index())


pareto = order_category_revenue.groupby('product_category_name_english')['Revenue'].sum().sort_values(ascending=False).head(10)


# Clean category names
pareto.index = (pareto.index.str.replace('_', ' ', regex=False).str.title())



# Cumulative percentage
cum_pct = pareto.cumsum() / pareto.sum() * 100

fig, ax1 = plt.subplots(figsize=(13,6))

# Bar chart
bars = ax1.bar(
    pareto.index,
    pareto.values,
    color='steelblue',
    edgecolor='black'
)

# Revenue labels
ax1.bar_label(
    bars,
   labels=[f'{x/1e6:.1f}M' for x in pareto.values] ,
    padding=3,
    fontsize=10
)

ax1.set_title(
    'Pareto Chart - Revenue by Product Category',
    fontsize=22,
    fontweight='bold'
)

ax1.set_xlabel(
    'Product Category',
    fontsize=14,
    fontweight='bold'
)

ax1.set_ylabel(
    'Revenue (R$)',
    fontsize=14,
    fontweight='bold'
)

# Revenue in Millions
ax1.yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f'{x/1e6:.1f}M')
)

plt.xticks(rotation=45, ha='right', fontsize=11)

# Secondary axis
ax2 = ax1.twinx()

ax2.plot(
    pareto.index,
    cum_pct,
    color='red',
    marker='o',
    linewidth=3
)

ax2.set_ylabel(
    'Cumulative Percentage (%)',
    fontsize=14,
    fontweight='bold',
    color='red'
)

ax2.set_ylim(0,105)

ax2.yaxis.set_major_formatter(
    mtick.PercentFormatter()
)

plt.tight_layout()


plt.savefig('../charts/Chart3_Revenue_by_Product_Category.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %%
plt.figure(figsize=(10,6))

plt.style.use('seaborn-v0_8-whitegrid')

month_order=[ 'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December']
monthlyordtrend=df.groupby('Purchase_Month')['order_id'].nunique().reindex(month_order,fill_value=0)
plt.plot(monthlyordtrend.index,monthlyordtrend.values,color='red',marker='o',linewidth=3)
plt.title('Monthly Orders Trend',fontsize=24,fontweight='bold')  
plt.xlabel(
    "Purchase Months",
    fontsize=15,
    fontweight='bold',color='orange'
)
plt.ylabel(
    "No. of Orders",
    fontsize=15,
    fontweight='bold',color='red'
)


plt.xticks(rotation=45,fontsize=17)
plt.yticks(fontsize=16)
plt.grid(alpha=0.7)
plt.tight_layout()


plt.savefig('../charts/Chart2_Monthly_Orders_Trend.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %% [markdown]
# Orders by Weekday

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(12,6))
weekdays=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
ordersbyweekdays=df.groupby('Day_of_Week')['order_id'].nunique().reindex(weekdays,fill_value=0)
bars=plt.bar(ordersbyweekdays.index,ordersbyweekdays.values)
plt.bar_label(bars,padding=3,fontsize=14)
plt.title('Orders by Weekdays',fontsize=24,fontweight='bold')  
plt.xlabel(
    "Weekkdays",
    fontsize=15,
    fontweight='bold',color='orange'
)
plt.ylabel(
    "No. of Orders",
    fontsize=15,
    fontweight='bold',color='red'
)

plt.xticks(rotation=30,fontsize=17)
plt.yticks(fontsize=16)
plt.grid(axis='y',alpha=0.7)
plt.tight_layout()


plt.savefig('../charts/Chart6_Orders_by_Weekdays.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %% [markdown]
# Customer Lifetime Value Distribution

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(12,6))

delivered_orders=df[df['order_status']=='delivered']
customer_clv = (
    delivered_orders.groupby('customer_unique_id')['total_price']
      .sum()
)


# Remove top 1% outliers for better visualization
customer_clv_plot = customer_clv[customer_clv <= customer_clv.quantile(0.99)]

plt.hist(
    customer_clv_plot,
    bins=100,
    color='steelblue',
    edgecolor='black'
)

plt.title('Customer Lifetime Value Distribution',
          fontsize=24,  
          fontweight='bold')

plt.xlabel(
    'Customer Lifetime Value (R$)',
    fontsize=15,
    fontweight='bold',
    color='orange'
)

plt.ylabel(
    'Number of Customers',
    fontsize=15,
    fontweight='bold',
    color='red'
)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.grid(axis='y', alpha=0.7)

plt.tight_layout()


plt.savefig('../charts/Chart7_Customer_Lifetime_Value_Distribution.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
print(customer_clv.describe())
# Out:
# count    93357.000000
# mean       173.405698
# std        259.400341
# min         10.070000
# 25%         64.000000
# 50%        110.600000
# 75%        188.400000
# max      13664.080000
# Name: total_price, dtype: float64

# %%
print(customer_clv.sort_values(ascending=False).head(10))
# Out:
# customer_unique_id
# 0a0a92112bd4c708ca5fde585afaa872    13664.08
# c4b224d2c784bae11ae98b6ae9f2454c    11111.40
# 85963fd37bfd387aa6d915d8a1065486    10553.28
# be74c431147c32ab2d7c7cef5e4a995f    10055.22
# edf81e1f3070b9dac83ec83dacdbb9bc     8389.52
# 58483a1c055dfb600f57c5b867174542     8068.88
# 1033eef37a760a832f9b2332ce23fdc5     8030.46
# da122df9eeddfedc1dc1f5349a1a690c     7571.63
# 301d1ce5a76b7e1bc47e5115bf5eb6ba     7413.70
# 763c8b1c9c68a0229c42c9fc6f662b93     7274.88
# Name: total_price, dtype: float64

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %% [markdown]
# chart to make for this question Which states generate the most customers?

# %%
plt.figure(figsize=(10,6))

statebycustomer=df.groupby('customer_state')['order_id'].nunique().nlargest(10).iloc[::-1]

bars=plt.barh(statebycustomer.index,statebycustomer.values)

plt.title('Orders by State', fontsize=24,  fontweight='bold')

plt.ylabel(
    'Customers States',
    fontsize=15,
    fontweight='bold',
    color='orange'
)

plt.xlabel(
    'Number of Customers',
    fontsize=15,
    fontweight='bold',
    color='red'
)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.grid(axis='y', alpha=0.7)

plt.tight_layout()



plt.savefig('../charts/Chart8_Orders_by_state.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %%
print(df['Delivery_Days'].isnull().sum())
# Out:
# 3421

# %%
print(df['review_score'].isnull().sum())
# Out:
# 997

# %%
print(df.loc[df['review_score'].isna(),"order_status"].value_counts())
# Out:
# order_status
# delivered      861
# shipped         88
# canceled        20
# unavailable     14
# processing       6
# invoiced         6
# created          2
# Name: count, dtype: int64

# %%
print(df.loc[df['Delivery_Days'].isna(),"order_status"].value_counts())
# Out:
# order_status
# shipped        1256
# canceled        743
# unavailable     652
# invoiced        378
# processing      376
# delivered         8
# created           5
# approved          3
# Name: count, dtype: int64

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(10,6))

# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

# Remove all rows from either Delivery_Days and review_score where delivered orders are missing  
delivered_orders=delivered_orders.dropna(subset=["Delivery_Days","review_score"])

#in this 
scatter_df=delivered_orders.groupby('order_id').agg({'Delivery_Days':'first','review_score':'first'}).reset_index()


plt.scatter(
    scatter_df['Delivery_Days'],
    scatter_df['review_score'],
    alpha=0.3,
    s=20
)   

plt.title(
    "Review Score vs Delivery Time",
    fontsize=20,
    fontweight='bold'
)
plt.xlabel(
    "Delivery Time (Days)",
    fontsize=14,
    fontweight='bold'
)
plt.ylabel(
    "Review Score",
    fontsize=14,
    fontweight='bold'
)

plt.xticks(fontsize=12)
plt.yticks( [1, 2, 3, 4, 5],fontsize=12)

plt.tight_layout()


plt.savefig('../charts/Chart9_Review_Score_vs_Delivery_time.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
print(df.loc[df['Delivery_Days'].isna(),"order_status"].value_counts())
# Out:
# order_status
# shipped        1256
# canceled        743
# unavailable     652
# invoiced        378
# processing      376
# delivered         8
# created           5
# approved          3
# Name: count, dtype: int64

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

# Remove all rows from Delivery_Days where delivered orders are missing  
delivered_orders=delivered_orders.dropna(subset=["Delivery_Days"])

avgdeldaysstate=delivered_orders.groupby(['order_id','customer_state']).agg(Delivery_Days=("Delivery_Days","first"))

avgdeldaysstate=avgdeldaysstate.groupby('customer_state')['Delivery_Days'].mean().round(1).nlargest(10).iloc[::-1]
bars = plt.barh(
    avgdeldaysstate.index,
    avgdeldaysstate.values,
    color='steelblue'
)
plt.bar_label(bars,padding=3,fontsize=14,fmt='%0.1f')
plt.title("Average Delivery Time by State",fontsize=20,fontweight='bold')
plt.xlabel("Average Delivery Time (Days)",fontsize=14,fontweight='bold')
plt.ylabel("Customer State",fontsize=14,fontweight='bold')

plt.xticks(fontsize=12)
plt.yticks(fontsize=11)

plt.tight_layout()


plt.savefig('../charts/Chart10_Average Delivery_Time_by_State.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
df.loc[df['order_delivered_customer_date'].isna(),['order_status']].value_counts()
# Out:
# order_status
# shipped         1256
# canceled         743
# unavailable      652
# invoiced         378
# processing       376
# delivered          8
# created            5
# approved           3
# Name: count, dtype: int64

# %% [markdown]
# revenue vs freight cost chart

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %%
df.loc[df['freight_value'].isna(), 'order_status'].value_counts()
# Out:
# order_status
# unavailable    645
# canceled       180
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %%
plt.style.use('seaborn-v0_8-whitegrid')


# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']



#In this no missing rows in frieght_value column for delivered_orders.

# Aggregate one row per order
order_data = delivered_orders.groupby('order_id').agg(Total_Price=('total_price','sum'),Freight_Cost=('freight_value','sum'))


# Create figure
fig, ax = plt.subplots(figsize=(12,6))

# Scatter plot
ax.scatter(
    order_data['Freight_Cost'],
    order_data['Total_Price'],
    color='royalblue',
    alpha=0.5,
    s=35
)


ax.set_title(
    'Revenue vs Freight Cost',
    fontsize=24,
    fontweight='bold'
)

ax.set_xlabel(
    'Freight Cost (R$)',
    fontsize=15,
    fontweight='bold',
    color='orange'
)

ax.set_ylabel(
    'Revenue (R$)',
    fontsize=15,
    fontweight='bold',
    color='red'
)

ax.tick_params(axis='both', labelsize=13)

ax.grid(alpha=0.7)


plt.savefig('../charts/Chart11_evenue_vs_Freight_Cost.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
df['freight_value'].dtypes
# Out:
# dtype('float64')

# %%
df['freight_value'].isnull().sum()
# Out:
# np.int64(833)

# %% [markdown]
# Which categories are expensive to ship?

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
# ...

# %%
df.loc[df['freight_value'].isna(), 'order_status'].value_counts()
# Out:
# order_status
# unavailable    645
# canceled       180
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(12,6))


# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']


#In this no missing rows in frieght_value column for delivered_orders.

avg_freight=delivered_orders.groupby(['order_id','product_category_name_english']).agg(Freight_Cost=("freight_value","sum"))
avg_freight=avg_freight.groupby('product_category_name_english')['Freight_Cost'].mean().round(1).nlargest(10).iloc[::-1]
bars=plt.barh(avg_freight.index,avg_freight.values,edgecolor='black',color='steelblue')
plt.bar_label(bars,padding=3,fontsize=14,fmt='%.1f')
plt.title("Top 10 Most Expensive Product Categories to Ship",fontsize=24,fontweight='bold')
plt.xlabel("Average Freight Cost (R$)",fontsize=16,fontweight='bold')
plt.ylabel('Product Category',fontsize=16,fontweight='bold')

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.tight_layout()


plt.savefig('../charts/Chart12_Top_10_Most_Expensive_Product_Categories_to_ship.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
# Late delivery flag
df['Late_Delivery'] = (df['order_delivered_customer_date'] > df['order_estimated_delivery_date']).astype(int)
df.to_csv('../datasets/Merged_Table/olist_ecommerce_clean.csv',index=False)

# %%
print(df['Late_Delivery'].value_counts())
# Out:
# Late_Delivery
# 0    110075
# 1      9065
# Name: count, dtype: int64

# %%
df[df['Late_Delivery'] == False].duplicated(subset='order_id').sum()
# Out:
# np.int64(18461)

# %%
print(df.loc[df['seller_id'].isna(),"order_status"].value_counts())
# Out:
# order_status
# unavailable    645
# canceled       180
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %%
print(df.loc[df['Late_Delivery'].isna(),"order_status"].value_counts())
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

#In this no missing rows in either late delivery and seller_id for delivered orders .

#One row per order per seller
seller_late=delivered_orders.groupby(['seller_id','order_id'])['Late_Delivery'].max().reset_index()

seller_late=seller_late.groupby('seller_id').agg(Total_Orders=('order_id','count'),Late_Orders=('Late_Delivery','sum'))

seller_late['Late_Rate']=(seller_late['Late_Orders']/seller_late['Total_Orders']*100)

seller_late=seller_late.sort_values('Late_Rate',ascending=False).head(10).iloc[::-1]

#Now make chart

plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(12,6))
bars=plt.barh(seller_late.index,seller_late['Late_Rate'],edgecolor='black')
plt.bar_label(bars,padding=3,fontsize=14,fmt='%1.0f%%')


plt.title("Top 10 Sellers with Highest Late Delivery Rate",fontsize=22,fontweight='bold')

plt.xlabel("Late Delivery Rate (%)",fontsize=14,fontweight='bold')

plt.ylabel("Seller ID",fontsize=14,fontweight='bold')

plt.gca().xaxis.set_major_formatter(mtick.PercentFormatter())

plt.xticks(fontsize=15)
plt.tight_layout()


plt.savefig('../charts/Chart13_Top_10_Sellers_with_Highest_Late_Delivery_Rate.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(8,8))


# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

delivered_status=delivered_orders['Late_Delivery'].value_counts()
labels=["On time" if x==0 else "late" for x in delivered_status.index]

wedges,texts,autotexts=plt.pie(delivered_status.values,labels=labels,colors=['#2B5C8F', '#E63946'],startangle=90,autopct='%1.0f%%',pctdistance=0.72,explode=(0,0.08),wedgeprops=dict(width=0.4,edgecolor='white',linewidth=2))
for text in texts:
    text.set_fontsize(16)
    text.set_color('black')
    text.set_fontweight('bold')

for autotext in autotexts:
    autotext.set_fontsize(16)    
    autotext.set_color('white')
    autotext.set_fontweight('bold')

plt.title('On-time vs Late Deliveries (Donut)')
plt.tight_layout()
plt.savefig('../charts/Chart14_On-time_vs_Late_Deliveries(Donut).png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %%
df.loc[df['freight_value'].isna(), 'order_status'].value_counts()
# Out:
# order_status
# unavailable    645
# canceled       180
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(12,6))

# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

#In this no missing rows in freight_value for delivered orders


freight_state=delivered_orders.groupby(['order_id','customer_state']).agg(Freight_Cost=('freight_value','sum'))
freight_state=freight_state.groupby('customer_state')['Freight_Cost'].mean().nlargest(10).iloc[::-1]
bars=plt.barh(freight_state.index,freight_state.values,edgecolor='black')
plt.bar_label(bars,padding=3,fontsize=14,fmt='%.0f')

plt.title("Average Freight Cost by State" ,fontsize=24,fontweight='bold')

plt.xlabel("Average Freight Cost (R$)",fontsize=16,fontweight='bold')

plt.ylabel("Customer State",fontsize=16,fontweight='bold')

plt.tight_layout()

plt.savefig('../charts/Chart15_Average_Freight_Cost_by_State.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()

# %% [markdown]
# 1 Dashboards :-Executive Overview

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')

fig, ax = plt.subplots(
    2, 3,
    figsize=(24, 12)
)


# ============================================================
# CHART 1 — MONTHLY REVENUE TREND
# ============================================================

# Keep only delivered orders
delivered_orders = df[
    df['order_status'] == 'delivered'
]

month_order = [
    'January', 'February', 'March', 'April',
    'May', 'June', 'July', 'August',
    'September', 'October', 'November', 'December'
]

# Group revenue
monthly_revenue = (
    delivered_orders
    .groupby('Purchase_Month')['total_price']
    .sum()
    .reindex(month_order, fill_value=0)
)

# Plot
ax[0, 0].plot(
    monthly_revenue.index,
    monthly_revenue.values,
    marker='o',
    linewidth=3,
    color='blue'
)

# Titles
ax[0, 0].set_title(
    "Monthly Revenue Trend",
    fontsize=24,
    fontweight='bold'
)

ax[0, 0].set_xlabel(
    "Months",
    fontsize=16,
    fontweight='bold'
)

ax[0, 0].set_ylabel(
    "Total Revenue",
    fontsize=16,
    fontweight='bold'
)

# Format Y-axis as Millions
ax[0, 0].yaxis.set_major_formatter(
    mtick.FuncFormatter(
        lambda x, pos: f'{x/1e6:.1f}M'
    )
)

# Show every month
ax[0, 0].set_xticks(range(len(month_order)))

ax[0, 0].set_xticklabels(
    month_order,
    rotation=45,
    fontsize=12,
    ha='right'
)

ax[0, 0].tick_params(
    axis='y',
    labelsize=13
)

ax[0, 0].grid(alpha=0.7)


# ============================================================
# CHART 2 — ORDERS BY PAYMENT METHOD
# ============================================================

ordersbypaymentmethod = (
    df.groupby('payment_type')['order_id']
    .nunique()
    .sort_values(ascending=False)
)

wedges, texts, autotexts = ax[0, 1].pie(
    ordersbypaymentmethod.values,
    labels=ordersbypaymentmethod.index,
    startangle=90,
    autopct='%1.1f%%',
    pctdistance=0.72,
    wedgeprops=dict(
        width=0.35,
        linewidth=2
    )
)

for autotext in autotexts:
    autotext.set_fontsize(16)
    autotext.set_color('white')
    autotext.set_fontweight('bold')

for text in texts:
    text.set_fontsize(16)
    text.set_color('black')
    text.set_fontweight('bold')

ax[0, 1].set_title(
    'Orders by Payment Method',
    fontsize=24,
    fontweight='bold'
)


# ============================================================
# CHART 4 — MONTHLY ORDERS TREND
# ============================================================

monthlyordtrend = (
    df.groupby('Purchase_Month')['order_id']
    .nunique()
    .reindex(month_order, fill_value=0)
)

ax[1, 0].plot(
    monthlyordtrend.index,
    monthlyordtrend.values,
    color='red',
    marker='o',
    linewidth=3
)

ax[1, 0].set_title(
    'Monthly Orders Trend',
    fontsize=24,
    fontweight='bold'
)

ax[1, 0].set_xlabel(
    "Purchase Months",
    fontsize=15,
    fontweight='bold'
)

ax[1, 0].set_ylabel(
    "No. of Orders",
    fontsize=15,
    fontweight='bold'
)

ax[1, 0].tick_params(
    axis='x',
    rotation=45,
    labelsize=12
)

ax[1, 0].tick_params(
    axis='y',
    labelsize=13
)

ax[1, 0].grid(alpha=0.7)


# ============================================================
# CHART 5 — TOP 10 STATES BY REVENUE
# ============================================================

statebycustomer = (
    delivered_orders
    .groupby('customer_state')['total_price']
    .sum()
    .nlargest(10)
    .sort_values()
)

bars = ax[1, 1].barh(
    statebycustomer.index,
    statebycustomer.values
)

ax[1, 1].set_title(
    'Top 10 States by Revenue',
    fontsize=24,
    fontweight='bold'
)

ax[1, 1].set_ylabel(
    'Customer State',
    fontsize=15,
    fontweight='bold'
)

ax[1, 1].set_xlabel(
    'Revenue (R$)',
    fontsize=15,
    fontweight='bold'
)

# Revenue in millions
ax[1, 1].xaxis.set_major_formatter(
    mtick.FuncFormatter(
        lambda x, pos: f'{x/1e6:.1f}M'
    )
)

ax[1, 1].tick_params(
    axis='both',
    labelsize=14
)

ax[1, 1].bar_label(
    bars,
    labels=[
        f'{x/1e6:.1f}M'
        for x in statebycustomer.values
    ],
    padding=3,
    fontsize=10
)

ax[1, 1].grid(
    axis='x',
    alpha=0.7
)


# ============================================================
# MERGE CHART 3 + CHART 6
# ============================================================

# Save the positions of Plot 3 and Plot 6
pos_top = ax[0, 2].get_position()
pos_bottom = ax[1, 2].get_position()

# Remove original Plot 3
ax[0, 2].remove()

# Remove original Plot 6
ax[1, 2].remove()

# Create one large axis covering ONLY the right column
ax_barh = fig.add_axes([
    pos_top.x0,                         # X position
    pos_bottom.y0,                      # Y position
    pos_top.width,                      # Width
    pos_top.y1 - pos_bottom.y0         # Height
])


# ============================================================
# CHART 6— PARETO: REVENUE BY PRODUCT CATEGORY
# ============================================================

pareto = (
    delivered_orders
    .groupby('product_category_name_english')['total_price']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

# Clean category names
pareto.index = (
    pareto.index
    .str.replace('_', ' ', regex=False)
    .str.title()
)

# Cumulative percentage
cum_pct = (
    pareto.cumsum()
    / pareto.sum()
    * 100
)


# ============================================================
# BAR CHART
# ============================================================

bars = ax_barh.bar(
    pareto.index,
    pareto.values,
    edgecolor='black'
)

# Revenue labels
ax_barh.bar_label(
    bars,
    labels=[
        f'{x/1e6:.1f}M'
        for x in pareto.values
    ],
    padding=3,
    fontsize=10
)

ax_barh.set_title(
    'Pareto Chart - Revenue by Product Category',
    fontsize=22,
    fontweight='bold'
)

ax_barh.set_xlabel(
    'Product Category',
    fontsize=16,
    fontweight='bold'
)

ax_barh.set_ylabel(
    'Revenue (R$)',
    fontsize=16,
    fontweight='bold'
)

# Revenue in millions
ax_barh.yaxis.set_major_formatter(
    mtick.FuncFormatter(
        lambda x, pos: f'{x/1e6:.1f}M'
    )
)

ax_barh.tick_params(
    axis='both',
    labelsize=16
    
)

# Rotate category names
plt.setp(
    ax_barh.get_xticklabels(),
    rotation=45,
    ha='right'
)


# ============================================================
# SECONDARY AXIS — CUMULATIVE %
# ============================================================

ax2 = ax_barh.twinx()

ax2.plot(
    pareto.index,
    cum_pct,
    marker='o',
    linewidth=3,
    color='red'
)

ax2.set_ylabel(
    'Cumulative Percentage (%)',
    fontsize=16,
    fontweight='bold'
)

ax2.set_ylim(
    0,
    105
)

ax2.yaxis.set_major_formatter(
    mtick.PercentFormatter()
)


# ============================================================
# MAIN DASHBOARD TITLE
# ============================================================

fig.suptitle(
    'Executive Overview | Brazilian E-Commerce Performance | 2016–2018',
    fontsize=28,
    fontweight='bold'
)

plt.tight_layout(
    rect=[0, 0, 1, 0.95]
)


# ============================================================
# SAVE
# ============================================================

plt.savefig(
    '../dashboard/Python_Dashboards/Executive Overview_Brazilian E-Commerce Performance_2016-2018.png',
    dpi=300,
    bbox_inches='tight',
    facecolor='white'
)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14880\3738437722.py:390: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(

# %% [markdown]
# 2- Customer Insights Dashboard

# %%
plt.style.use('seaborn-v0_8-whitegrid')
fig,ax=plt.subplots(1,3,figsize=(24,12),constrained_layout=True)
plt.suptitle("Product Insights")

#chart 1 order distributuion by state
ordersbystate=df.groupby('customer_state')['order_id'].nunique().nlargest(10).iloc[::-1]
bars=ax[0].barh(ordersbystate.index,ordersbystate.values,edgecolor='black')
ax[0].bar_label(bars,padding=3,fontsize=14)
ax[0].set_title('Orders by State', fontsize=24,  fontweight='bold')

ax[0].set_ylabel(
    'Customers States',
    fontsize=15,
    fontweight='bold',
    color='orange'
)

ax[0].set_xlabel(
    'Number of Customers',
    fontsize=15,
    fontweight='bold',
    color='red'
)

ax[0].tick_params(axis='both',labelsize=14)

ax[0].grid(axis='y', alpha=0.7)








# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

# Remove all rows from either Delivery_Days and review_score where delivered orders are missing  
delivered_orders=delivered_orders.dropna(subset=["Delivery_Days","review_score"])

#in this 
scatter_df=delivered_orders.groupby('order_id').agg({'Delivery_Days':'first','review_score':'first'}).reset_index()


ax[1].scatter(
    scatter_df['Delivery_Days'],
    scatter_df['review_score'],
    alpha=0.3,
    s=20
)   

ax[1].set_title(
    "Review Score vs Delivery Time",
    fontsize=20,
    fontweight='bold'
)
ax[1].set_xlabel(
    "Delivery Time (Days)",
    fontsize=14,
    fontweight='bold'
)
ax[1].set_ylabel(
    "Review Score",
    fontsize=14,
    fontweight='bold'
)

ax[1].tick_params(axis='both',labelsize=12)
ax[1].set_yticks( [1, 2, 3, 4, 5])






order_time_sort=['Morning','Afternoon','Evening','Night']
order_time=df.groupby('time_of_day')['order_id'].nunique().reindex(order_time_sort).sort_values(ascending=False)
bars=ax[2].bar(order_time.index,order_time.values)
ax[2].bar_label(bars,padding=3,fontsize=14)
ax[2].set_title("Orders by Time of Day",fontsize=24,fontweight='bold')  
ax[2].set_xlabel(
    "Time of Day",
    fontsize=15,
    fontweight='bold'
)
ax[2].set_ylabel(
    "No. of Orders",
    fontsize=15,
    fontweight='bold'
)
ax[2].tick_params(axis='both',labelsize=15)
ax[2].grid(axis='y',alpha=0.7)

plt.savefig(
    "../dashboard/Python_Dashboards/Customer_Analytics.png",
    dpi=300,
    bbox_inches='tight'
)

# %% [markdown]
# 3- Product Insights

# %%
plt.style.use('seaborn-v0_8-talk')

fig, ax = plt.subplots(2, 2,figsize=(22, 10),constrained_layout=True)

plt.suptitle('Product Insights',fontsize=32)

# CHART 1 — Pareto: Revenue by Product Category


# Keep only delivered orders
delivered_orders = df[
    df['order_status'] == 'delivered'
]

# Revenue by product category
pareto = (
    delivered_orders
    .groupby('product_category_name_english')['total_price']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

# Clean category names
pareto.index = (
    pareto.index
    .str.replace('_', ' ', regex=False)
    .str.title()
)

# Cumulative percentage
cum_pct = pareto.cumsum() / pareto.sum() * 100


# Bar chart
bars = ax[0, 0].bar(
    pareto.index,
    pareto.values,
    edgecolor='black'
)

# Revenue labels
ax[0, 0].bar_label(
    bars,
    labels=[f'{x/1e6:.1f}M' for x in pareto.values],
    padding=3,
    fontsize=10
)

ax[0, 0].set_title(
    'Pareto Chart - Revenue by Product Category',
    fontsize=22,
    fontweight='bold'
)

ax[0, 0].set_xlabel(
    'Product Category',
    fontsize=14,
    fontweight='bold'
)

ax[0, 0].set_ylabel(
    'Revenue (R$)',
    fontsize=14,
    fontweight='bold'
)

# Revenue in millions
ax[0, 0].yaxis.set_major_formatter(
    mtick.FuncFormatter(
        lambda x, pos: f'{x/1e6:.1f}M'
    )
)

ax[0, 0].tick_params(
    axis='both',
    labelsize=11
)

# Rotate category names
plt.setp(
    ax[0, 0].get_xticklabels(),
    rotation=45,
    ha='right'
)


# Secondary axis
ax2 = ax[0, 0].twinx()

ax2.plot(
    pareto.index,
    cum_pct,
    marker='o',
    linewidth=3
)

ax2.set_ylabel(
    'Cumulative Percentage (%)',
    fontsize=14,
    fontweight='bold'
)

ax2.set_ylim(0, 105)

ax2.yaxis.set_major_formatter(
    mtick.PercentFormatter()
)










# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']

#In this no missing rows in frieght_value column for delivered_orders.

# Aggregate one row per order
order_data = delivered_orders.groupby('order_id').agg(Total_Price=('total_price','sum'),Freight_Cost=('freight_value','sum'))


# Scatter plot
ax[0,1].scatter(
    order_data['Freight_Cost'],
    order_data['Total_Price'],
    color='royalblue',
    alpha=0.5,
    s=35
)


ax[0,1].set_title(
    'Revenue vs Freight Cost',
    fontsize=24,
    fontweight='bold'
)

ax[0,1].set_xlabel(
    'Freight Cost (R$)',
    fontsize=15,
    fontweight='bold',
    color='orange'
)

ax[0,1].set_ylabel(
    'Revenue (R$)',
    fontsize=15,
    fontweight='bold',
    color='red'
)

ax[0,1].tick_params(axis='both', labelsize=13)

ax[0,1].grid(alpha=0.7)





# CHART 3 — Orders by Product Category


ordersbyproduct = (df.groupby('product_category_name_english')['order_id'].nunique().nlargest(10).iloc[::-1])

# Clean names
ordersbyproduct.index = (ordersbyproduct.index.str.replace('_', ' ', regex=False).str.title())

bars = ax[1, 0].barh(ordersbyproduct.index,ordersbyproduct.values,edgecolor='black')

ax[1, 0].bar_label(bars,padding=4,fontsize=14)

ax[1, 0].set_title('Top 10 Product Categories by Orders',fontsize=22,fontweight='bold')

ax[1, 0].set_xlabel('Number of Orders',fontsize=15,fontweight='bold')

ax[1, 0].set_ylabel('Product Category',fontsize=15,fontweight='bold')

ax[1, 0].tick_params(axis='both',labelsize=12)

ax[1, 0].grid(axis='x',alpha=0.7)




# CHART 4 — Average Freight Cost by Product Category



# Keep only delivered orders
delivered_orders=df[df['order_status']=='delivered']


#In this no missing rows in frieght_value column for delivered_orders.

avg_freightbyproduct=delivered_orders.groupby(['order_id','product_category_name_english']).agg(Freight_Cost=("freight_value","sum"))

avg_freightbyproduct=avg_freightbyproduct.groupby('product_category_name_english')['Freight_Cost'].mean().round(1).nlargest(10).iloc[::-1]

avg_freightbyproduct.index=avg_freightbyproduct.index.str.replace('_',' ',regex=False).str.title()

bars=ax[1,1].barh(avg_freightbyproduct.index,avg_freightbyproduct.values,edgecolor='black',color='steelblue')
ax[1,1].bar_label(bars,padding=3,fontsize=14,fmt='%.1f')

ax[1,1].set_title("Top 10 Most Expensive Product Categories to Ship",fontsize=24,fontweight='bold')
ax[1,1].set_xlabel("Average Freight Cost (R$)",fontsize=16,fontweight='bold')
ax[1,1].set_ylabel('Product Category',fontsize=16,fontweight='bold')

ax[1,1].tick_params(axis='x',labelsize=15)
ax[1,1].tick_params(axis='y',labelsize=15)
ax[1,1].grid(axis='x',alpha=0.7)

plt.savefig(
    '../dashboard/Python_Dashboards/Product_Insights.png',
    dpi=300,
    bbox_inches='tight'
)
plt.show()

# %%
import matplotlib.ticker as mtick

plt.style.use('seaborn-v0_8-whitegrid')
fig,ax=plt.subplots(2,2,figsize=(24,12))
plt.suptitle('Logistics & Delivery Analytics Dashboard',fontsize=(32),fontweight='bold')

# COLORS
blue='#1F5A85'
dark_blue='#123B5D'
red='#D9534F'



# CHART 1 - AVERAGE DELIVERY TIME BY STATE
delivered_orders=df[df['order_status']=='delivered']
delivered_orders=delivered_orders.dropna(subset=['Delivery_Days'])

avgdeldaysstate=delivered_orders.groupby(['order_id','customer_state']).agg(Delivery_Days=('Delivery_Days','first'))
avgdeldaysstate=avgdeldaysstate.groupby('customer_state')['Delivery_Days'].mean().round(1).nlargest(10).iloc[::-1]
bars=ax[0,0].barh(avgdeldaysstate.index,avgdeldaysstate.values,color=blue,edgecolor='white')
ax[0,0].bar_label(bars,fmt='%.1f',padding=3,fontsize=9)
ax[0,0].set_title('Average Delivery Time by State',fontsize=15,fontweight='bold',color=dark_blue,pad=12)
ax[0,0].set_xlabel('Average Delivery Time (Days)',fontsize=10,fontweight='bold')
ax[0,0].set_ylabel('State',fontsize=10,fontweight='bold')
ax[0,0].tick_params(axis='both',labelsize=9)
ax[0,0].grid(axis='x',alpha=0.2)

# CHART 2 - ON TIME VS LATE


delivered_orders=df[df['order_status']=='delivered']

delivered_status=delivered_orders['Late_Delivery'].value_counts().sort_index()
labels=['On time' if x==0 else 'Late' for x in delivered_status.index]
colors=[blue,red]
wedges,texts,autotexts=ax[0,1].pie(delivered_status.values,labels=labels,colors=colors,startangle=90,autopct='%1.0f%%',pctdistance=0.72,explode=(0,0.06),wedgeprops=dict(width=0.38,edgecolor='white',linewidth=2))
for text in texts:
    text.set_fontsize(10)
    text.set_fontweight('bold')
for autotext in autotexts:
    autotext.set_fontsize(10)
    autotext.set_fontweight('bold')
    autotext.set_color('white')
ax[0,1].set_title('On-time vs Late Deliveries',fontsize=15,fontweight='bold',color=dark_blue,pad=12)


# CHART 3 - AVERAGE FREIGHT COST BY STATE


freight_state=delivered_orders.groupby(['order_id','customer_state']).agg(Freight_Cost=('freight_value','sum'))
freight_state=freight_state.groupby('customer_state')['Freight_Cost'].mean().nlargest(10).iloc[::-1]
bars=ax[1,0].barh(freight_state.index,freight_state.values,color=blue,edgecolor='white')
ax[1,0].bar_label(bars,fmt='%.0f',padding=3,fontsize=9)
ax[1,0].set_title('Average Freight Cost by State',fontsize=15,fontweight='bold',color=dark_blue,pad=12)
ax[1,0].set_xlabel('Average Freight Cost (R$)',fontsize=10,fontweight='bold')
ax[1,0].set_ylabel('State',fontsize=10,fontweight='bold')
ax[1,0].tick_params(axis='both',labelsize=9)
ax[1,0].spines[['top','right','left','bottom']].set_visible(False)
ax[1,0].grid(axis='x',alpha=0.2)

# CHART 4 - AVERAGE DELIVERY TIME TREND


Month_Order=['January','February','March','April','May','June','July','August','September','October','November','December']
avgdeliverydaysbymonth=delivered_orders.groupby(['order_id','Purchase_Month']).agg(Delivery_Days=('Delivery_Days','first'))
avgdeliverydaysbymonth=avgdeliverydaysbymonth.groupby('Purchase_Month')['Delivery_Days'].mean().reindex(Month_Order)
ax[1,1].plot(avgdeliverydaysbymonth.index,avgdeliverydaysbymonth.values,marker='o',markersize=6,linewidth=2.5,color=blue)

ax[1,1].set_title('Average Delivery Time Trend',fontsize=15,fontweight='bold',color=dark_blue,pad=12)
ax[1,1].set_ylabel('Average Delivery Days',fontsize=10,fontweight='bold')
ax[1,1].set_xlabel('Purchase Month',fontsize=10,fontweight='bold')
ax[1,1].tick_params(axis='both',labelsize=9)
ax[1,1].grid(alpha=0.2)


# SAVE

plt.savefig('../dashboard/Python_Dashboards/Logistics & Delivery Analytics Dashboard.png',dpi=300,bbox_inches='tight',facecolor='white')
plt.show()
